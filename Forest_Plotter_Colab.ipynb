# %% [markdown]
# # Forest Plotter\n\nRun the cells below, then open the temporary Cloudflare link that appears in the final cell output.\n\nThe link only works while this Colab runtime is active.

# %%
# Clone Forest Plotter from GitHub.\n\nREPO_URL = "https://github.com/GabrielBonassi77/Gabe-Forest-Plotter.git"\n\nimport os\nfrom pathlib import Path\n\n!rm -rf forest-plotter\n!git clone --depth 1 "$REPO_URL" forest-plotter\nos.chdir("/content/forest-plotter")\nprint("Working directory:", Path.cwd())

# %% [markdown]
# If you uploaded the project files manually instead of cloning GitHub, skip the cell above and run this instead:

# %%
# Optional manual-upload path:\n# 1. Upload app.py, forest_plotter.py, requirements.txt, and colab_app.py into /content.\n# 2. Uncomment and run this cell.\n\n# import os\n# os.chdir("/content")\n# print("Working directory:", os.getcwd())

# %%
# !pip -q install -r requirements.txt\n!wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb\n!dpkg -i cloudflared-linux-amd64.deb >/dev/null\nprint("Installed dependencies and cloudflared.")

# %%
# !python colab_app.py
